# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns

# %%
data = pd.read_csv('spotifyRefinedTarget.csv')

# %%
data.head(3)
# Out:
#                       name                                            artists  \
# 0  Clancy Lowered the Boom                                     ['Dennis Day']
# 1                Gati Bali  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...
# 2             Gati Mardika  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...
#
#    percentage  danceability  energy  liveness  loudness  speechiness  \
# 0    0.660748         0.819   0.341     0.160   0.47559       0.4150
# 1    0.506691         0.328   0.166     0.101   0.45150       0.0339
# 2    0.619534         0.697   0.346     0.130   0.47494       0.0700
#
#       tempo  mode2  acousticness  instrumentalness
# 0  0.253900   0.25         0.732             0.000
# 1  0.459746   0.25         0.961             0.913
# 2  0.499267   0.25         0.579             0.168

# %%
X = data[['acousticness','instrumentalness']]

# %%
kmeans = KMeans(n_clusters=7)
model = kmeans.fit(X)

# %%
kmeans.labels_
# Out:
# array([4, 0, 1, ..., 5, 5, 5], dtype=int32)

# %%
kmeans.cluster_centers_
# Out:
# array([[0.89940893, 0.87207958],
#        [0.5932536 , 0.01030616],
#        [0.30277906, 0.01264889],
#        [0.11584512, 0.71515952],
#        [0.86548426, 0.01423299],
#        [0.05155409, 0.01864829],
#        [0.81419339, 0.47256074]])

# %%
sns.scatterplot(data=X, x='acousticness', y='instrumentalness', hue=kmeans.labels_)
# Out:
# <AxesSubplot:xlabel='acousticness', ylabel='instrumentalness'>

# %%
temp = data.copy()

# %%
temp['klabels'] = kmeans.labels_

# %%
temp.head(3)
# Out:
#                       name                                            artists  \
# 0  Clancy Lowered the Boom                                     ['Dennis Day']
# 1                Gati Bali  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...
# 2             Gati Mardika  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...
#
#    percentage  danceability  energy  liveness  loudness  speechiness  \
# 0    0.660748         0.819   0.341     0.160   0.47559       0.4150
# 1    0.506691         0.328   0.166     0.101   0.45150       0.0339
# 2    0.619534         0.697   0.346     0.130   0.47494       0.0700
#
#       tempo  mode2  acousticness  instrumentalness  klabels
# 0  0.253900   0.25         0.732             0.000        4
# 1  0.459746   0.25         0.961             0.913        0
# 2  0.499267   0.25         0.579             0.168        1

# %%
temp[temp['klabels']==2]
# Out:
#                                           name  \
# 332     On The Sunny Side Of The Street - Live
# 380                             Mack the Knife
# 447     On The Sunny Side Of The Street - Live
# 462                              The New World
# 1001        Blue Xmas (To Whom It May Concern)
# ...                                        ...
# 133029                                 Red Eye
# 133034                        La Playa - Remix
# 133042                                Sunblind
# 133044                  NASTY GIRL / ON CAMERA
# 133047             Halloweenie III: Seven Days
#
#                                      artists  percentage  danceability  \
# 332                      ['Louis Armstrong']    0.755087         0.608
# 380                      ['Louis Armstrong']    0.661248         0.493
# 447                      ['Louis Armstrong']    0.748029         0.614
# 462                           ['Joe Quartz']    0.353274         0.758
# 1001                         ['Miles Davis']    0.537824         0.432
# ...                                      ...         ...           ...
# 133029        ['YoungBoy Never Broke Again']    0.712692         0.485
# 133034  ['Myke Towers', 'Maluma', 'Farruko']    0.485008         0.775
# 133042                       ['Fleet Foxes']    0.640415         0.562
# 133044                             ['Gunna']    0.654404         0.598
# 133047                          ['Ashnikko']    0.707672         0.717
#
#         energy  liveness  loudness  speechiness     tempo  mode2  \
# 332      0.388    0.9660   0.49009       0.0733  0.505133   0.25
# 380      0.400    0.2190   0.44825       0.1650  0.742237   0.25
# 447      0.363    0.9640   0.48951       0.0541  0.503563   0.25
# 462      0.376    0.0884   0.45524       0.0587  0.383304   0.00
# 1001     0.228    0.1720   0.43242       0.0667  0.395825   0.25
# ...        ...       ...       ...          ...       ...    ...
# 133029   0.814    0.1120   0.56093       0.1380  0.666225   0.25
# 133034   0.633    0.2190   0.56668       0.1330  0.583367   0.00
# 133042   0.686    0.1250   0.51520       0.0249  0.429392   0.25
# 133044   0.472    0.1080   0.49009       0.2580  0.500333   0.25
# 133047   0.753    0.1010   0.53980       0.0605  0.574733   0.25
#
#         acousticness  instrumentalness  klabels
# 332            0.410          0.000002        2
# 380            0.295          0.000000        2
# 447            0.383          0.000001        2
# 462            0.309          0.020200        2
# 1001           0.365          0.000004        2
# ...              ...               ...      ...
# 133029         0.217          0.000000        2
# 133034         0.201          0.000000        2
# 133042         0.310          0.022500        2
# 133044         0.204          0.000015        2
# 133047         0.206          0.000000        2
#
# [22569 rows x 13 columns]

# %%
smallData = data.copy()

# %%
smallData = smallData.iloc[:,:3]

# %%
smallData['error'] = 0

# %%
smallData.head(3)
# Out:
#                       name                                            artists  \
# 0  Clancy Lowered the Boom                                     ['Dennis Day']
# 1                Gati Bali  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...
# 2             Gati Mardika  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...
#
#    percentage  error
# 0    0.660748      0
# 1    0.506691      0
# 2    0.619534      0

# %%
smallData.loc[0:2,'error'] #loc 진짜 index / iloc 숫자 idx  iloc은 슬라이싱에서 and 포함x
#pandas sort api
#for loop x ->map 함수 이용
#numpy로 export해서..
# Out:
# 0    0
# 1    0
# 2    0
# Name: error, dtype: int64

# %%
import time
def withPositivity(positivity, data):
    start = time.time()
    for i in range(0,len(data)):
        musicPositivity = data.loc[i,'percentage']
        #print(musicPositivity)
        error = abs(positivity - musicPositivity)
        #print(error)
        data.loc[i,'error'] = error
        #index 의 i -> loc사용
    sortedData = data.sort_values(by='error', ascending=True)
    finish = time.time()
    print('time' , finish-start)
    print(sortedData.head(3))

# %%
withPositivity(0.8, smallData)
# Out:
# time 28.11272883415222
#                                            name  \
# 1624   Final Speech (From "The Great Dictator")
# 1627   Final Speech - From "The Great Dictator"
# 67583                (Can't You) Trip Like I Do
#
#                                 artists  percentage     error
# 1624                ['Charlie Chaplin']    0.800010  0.000010
# 1627                ['Charlie Chaplin']    0.800010  0.000010
# 67583  ['Filter', 'The Crystal Method']    0.800025  0.000025

# %%
smallData.iloc[1624,:]
# Out:
# name          Final Speech (From "The Great Dictator")
# artists                            ['Charlie Chaplin']
# percentage                                     0.80001
# error                                          0.00001
# Name: 1624, dtype: object

# %%
smallData.iloc[1627,:]
# Out:
# name          Final Speech - From "The Great Dictator"
# artists                            ['Charlie Chaplin']
# percentage                                     0.80001
# error                                          0.00001
# Name: 1627, dtype: object

# %%
'''
 1. nlp 결과가 벡터로 나올 수 있는지? (0, 1, 2)
 2. x축 acoustic, y축 instrumentalness, z축 percentage 3차원에 뿌리고 nlp결과를 떨군다
 축이 같지 않아서 불가능.. 
 
 3. 머신러닝 알고리즘이 있는지? 코사인 유사도 annoy
 knn을 음악데이터로 먼저 돌리고, 
 
 4. 데이터 라벨링
 
 문장을 input으로 넣고 label이
'''
